# %%
import prisma_sase
import cloudgenix

# %%
#
# Authenticate using Service Account - SASE Portal
#

CLIENT_ID = "paste client ID"
CLIENT_SECRET = "paste client secret"
TSG = "paste TSG ID"


sdk = prisma_sase.API(ssl_verify=False)
sdk.interactive.login_secret(client_id=CLIENT_ID, client_secret=CLIENT_SECRET, tsg_id=TSG)
# Out:
# True

# %% [markdown]
# # EVENTS

# %% [markdown]
# ## Event Query Data Structure
#
#
# **limit:**
# - Max count is 100. API response contains "total_count" and "included_count".
# - If "total_count" is greater than "included_count", use "_offset" in API response to get delta events
#
# **type:**
# - Allowed values are alarm and alert
#
# **site:**
# - List of site IDs
# - Retrieves alarms specific to the site IDs provided
#
# **category:**
# - Allowed values are network, device, application, policy, spokeha, authentication
# - Retrieves category specific alarms
#
# **code:**
# - Filter on event code.
# - Review document for list of allowed codes
# https://docs.paloaltonetworks.com/prisma/prisma-sd-wan/prisma-sd-wan-incidents-and-alerts/incident-and-alert-events/incident-and-alert-event-codes
#
# **correlation_id:**
# - Retrieve alarms specific to a correlation ID
# - Alarms raised and cleared for the same condition are associated with each other via the correlation_id
# - Can be used to determine when a condition was raised & cleared
#
#
# **severity:**
# - Filter on alarm severity
# - Allowed values: critical, major, minor
#
# **priority:**
# - Filter on alarm priority
# - Allowed values: p1, p2, p3, p4, p5
#
# **acknowledged:**
# - To include alarms acknowledged by operators, set this flag to True
#
#
# **suppressed:**
# - To include alarms suppressed by the Event Correlation & Suppression engine, set this flag to True
#
# **suppressed_info:**
# - Used to retrieve alarms suppressed due to the summary event
# - Dict expects attribute "summary_event_ids" (list)
#
#
# **start_time & end_time:**
# - Supported timestamp ISO8601 UTC only i.e. YYYY-MM-DDThh:mm:ssZ or YYYY-MM-DDThh:mm:ss.sssZ
# - To retrieve standing alarms, set **both** start_time and end_time to None/null
# - Setting either start_time or end_time to a non-null value will only return alarms raised and cleared in that time range

# %% [markdown]
# ## Retrieve Standing Events

# %%
data = {
    "limit":{
        "count":100,
        "sort_on":"time",
        "sort_order":"descending"
    },
    "query":{
        "type":["alarm"],
        "site": [],
        "category":[],
        "code":[],
        "correlation_id": []
    },
    "start_time": None,
    "end_time": None,
    "severity":[],
    "priority":[],
    "acknowledged":False,
    "suppressed":False,
    "suppressed_info":None,
    
}

resp = sdk.post.events_query(data=data)
print("*******************\n{}\n*******************\n\n".format(resp.cgx_content.get("total_count")))
events = resp.cgx_content.get("items", None)
for event in events:
    print(event["time"])
# Out:
# *******************
# 56
# *******************
#
#
# 2023-12-07T13:54:10.327000Z
# 2023-12-07T13:52:23.298000Z
# 2023-12-07T13:50:32.139000Z
# 2023-12-07T08:49:15.869000Z
# 2023-12-06T20:22:32.153000Z
# 2023-12-06T19:33:39.952000Z
# 2023-11-29T17:43:18.489000Z
# 2023-11-06T05:22:52.229000Z
# 2023-11-06T05:21:42.398000Z
# 2023-10-18T22:25:02.142000Z
# 2023-10-18T22:25:02.142000Z
# 2023-10-18T22:15:00.376000Z
# 2023-10-18T22:07:21.168000Z
# 2023-10-18T21:46:18.385000Z
# 2023-10-18T21:20:47.023000Z
# 2023-10-18T21:20:46.773000Z
# 2023-10-15T22:35:02.688000Z
# 2023-10-15T22:35:02.688000Z
# 2023-10-15T22:25:00.285000Z
# 2023-10-15T22:15:37.113000Z
# 2023-10-12T18:12:25.905000Z
# 2023-10-12T18:12:25.859000Z
# 2023-10-12T18:12:25.800000Z
# 2023-10-05T21:58:31.010000Z
# 2023-10-05T05:02:24.078000Z
# 2023-10-04T20:15:02.430000Z
# 2023-10-04T20:15:02.430000Z
# 2023-10-04T20:05:00.393000Z
# 2023-10-04T19:53:52.427000Z
# 2023-10-03T23:47:52.714000Z
# 2023-10-03T23:37:10.648000Z
# 2023-10-03T23:36:05.704000Z
# 2023-10-03T23:36:05.387000Z
# 2023-10-03T23:36:03.559000Z
# 2023-10-03T23:35:59.533000Z
# 2023-10-03T23:35:55.730000Z
# 2023-10-03T23:35:52.826000Z
# 2023-10-03T23:35:49.940000Z
# 2023-10-03T23:35:39.837000Z
# 2023-10-03T18:04:25.336000Z
# 2023-10-03T18:04:25.214000Z
# 2023-10-03T18:03:29.148000Z
# 2023-09-25T05:04:19.517000Z
# 2023-09-25T05:04:19.237000Z
# 2023-09-25T05:04:19.136000Z
# 2023-09-25T05:04:19.040000Z
# 2023-09-11T23:21:58.970000Z
# 2023-09-11T23:13:38.673000Z
# 2023-09-01T18:35:01.635000Z
# 2023-09-01T18:35:00.302000Z
# 2023-09-01T18:30:01.800000Z
# 2023-09-01T18:30:01.800000Z
# 2023-09-01T18:30:01.800000Z
# 2023-09-01T18:25:00.248000Z
# 2023-07-25T18:20:00.582000Z
# 2023-06-13T20:40:24.936000Z

# %% [markdown]
# ## Retrieve Cleared Events

# %%
data = {
    "limit":{
        "count":100,
        "sort_on":"time",
        "sort_order":"descending"
    },
    "query":{
        "type":["alarm"],
        "site": [],
        "category":[],
        "code":[],
        "correlation_id": []
    },
    "start_time": "2023-12-01T00:00:00Z",
    "end_time": None,
    "severity":[],
    "priority":[],
    "acknowledged":False,
    "suppressed":False,
    "suppressed_info":None
}

resp = sdk.post.events_query(data=data)
print("*******************\n{}\n*******************\n\n".format(resp.cgx_content.get("total_count")))
print("*******************\n{}\n*******************\n\n".format(resp.cgx_content.get("included_count")))

#prisma_sase.jd_detailed(resp)
events = resp.cgx_content.get("items", None)
for event in events:
    print(event["code"],event["correlation_id"], event["time"], event["cleared"])
# Out:
# *******************
# 29119
# *******************
#
#
# *******************
# 100
# *******************
#
#
# NETWORK_ANYNETLINK_DOWN t0wNYWhy 2023-12-07T13:54:10.327000Z False
# SITE_CONNECTIVITY_DEGRADED VcDYX0OX 2023-12-07T13:52:24.747000Z True
# NETWORK_ANYNETLINK_DOWN oiH40Gdg 2023-12-07T13:52:23.298000Z False
# SITE_CONNECTIVITY_DEGRADED zda8MpIm 2023-12-07T13:50:33.770000Z True
# NETWORK_ANYNETLINK_DOWN 3RSgbbmC 2023-12-07T13:50:32.139000Z False
# NETWORK_ANYNETLINK_DEGRADED sVKxXL1v 2023-12-07T13:45:52.067000Z True
# NETWORK_ANYNETLINK_DEGRADED 7UrNZ8PY 2023-12-07T13:45:50.681000Z True
# NETWORK_ANYNETLINK_DEGRADED 7UrNZ8PY 2023-12-07T13:45:49.759000Z False
# NETWORK_ANYNETLINK_DEGRADED sVKxXL1v 2023-12-07T13:45:49.690000Z False
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:45:01.961000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:45:01.474000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:45:01.252000Z True
# SITE_CONNECTIVITY_DEGRADED rnS2qUHH 2023-12-07T13:40:33.708000Z True
# SITE_CONNECTIVITY_DEGRADED CT5yhEH7 2023-12-07T13:40:33.708000Z True
# SITE_CONNECTIVITY_DEGRADED aBfem6Io 2023-12-07T13:40:32.866000Z True
# SITE_CONNECTIVITY_DEGRADED je11Sq88 2023-12-07T13:40:32.866000Z True
# NETWORK_ANYNETLINK_DOWN FMyz7CRx 2023-12-07T13:40:31.874000Z False
# NETWORK_ANYNETLINK_DOWN bsRdpw1o 2023-12-07T13:40:31.636000Z False
# NETWORK_ANYNETLINK_DEGRADED 660A1lL1 2023-12-07T13:37:41.160000Z True
# NETWORK_ANYNETLINK_DEGRADED fZPKYQ2y 2023-12-07T13:37:40.166000Z True
# NETWORK_ANYNETLINK_DEGRADED fZPKYQ2y 2023-12-07T13:37:39.168000Z False
# NETWORK_ANYNETLINK_DEGRADED 660A1lL1 2023-12-07T13:37:38.937000Z False
# NETWORK_ANYNETLINK_DEGRADED 9J1MZBMS 2023-12-07T13:34:49.913000Z True
# NETWORK_ANYNETLINK_DEGRADED 0JpAz2BU 2023-12-07T13:34:49.416000Z True
# NETWORK_ANYNETLINK_DEGRADED 0JpAz2BU 2023-12-07T13:34:48.629000Z False
# NETWORK_ANYNETLINK_DEGRADED 9J1MZBMS 2023-12-07T13:34:48.563000Z False
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:31:02.275000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:31:01.860000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:31:01.691000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:53.836000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:53.412000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:53.232000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:52.625000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:52.194000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:52.013000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:49.403000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:48.977000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:48.800000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:47.093000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:46.665000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:46.502000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:37.777000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:37.393000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:37.207000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:36.443000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:36.071000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:35.813000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:35.076000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:34.631000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:34.441000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:32.651000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:32.195000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:32.021000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:28.377000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:27.977000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:27.805000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:23.918000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:23.506000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:23.326000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:22.845000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:22.429000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:22.220000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:15.308000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:14.887000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:14.720000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:12.627000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:11.960000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:11.778000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:11.474000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:11.047000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:10.860000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:09.794000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:09.382000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:09.192000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:07.959000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:07.569000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:07.383000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:06.807000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:06.385000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:06.209000Z True
# NETWORK_ANYNETLINK_DEGRADED Cg9gTkEV 2023-12-07T13:30:05.991000Z True
# NETWORK_ANYNETLINK_DEGRADED 3d87vyJs 2023-12-07T13:30:05.498000Z True
# NETWORK_ANYNETLINK_DEGRADED 3d87vyJs 2023-12-07T13:30:04.699000Z False
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:04.687000Z True
# NETWORK_ANYNETLINK_DEGRADED Cg9gTkEV 2023-12-07T13:30:04.642000Z False
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:04.200000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:04.025000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:02.264000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:01.784000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:30:01.601000Z True
# NETWORK_ANYNETLINK_DEGRADED XgoZ4Kc6 2023-12-07T13:27:56.288000Z True
# NETWORK_ANYNETLINK_DEGRADED I6HoQDqk 2023-12-07T13:27:54.798000Z True
# NETWORK_ANYNETLINK_DEGRADED I6HoQDqk 2023-12-07T13:27:53.809000Z False
# NETWORK_ANYNETLINK_DEGRADED XgoZ4Kc6 2023-12-07T13:27:53.770000Z False
# FLAP_RATE_EXCEEDED zQRXCxwu 2023-12-07T13:23:00.473000Z True
# FLAP_RATE_EXCEEDED BPNiNIiB 2023-12-07T13:23:00.470000Z True
# NETWORK_ANYNETLINK_DEGRADED UobJogYf 2023-12-07T13:22:22.435000Z True
# NETWORK_ANYNETLINK_DEGRADED UobJogYf 2023-12-07T13:22:20.092000Z False
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:15:01.711000Z True
# USER_ID_DIRECTORY_SYNC_FAILED None 2023-12-07T13:15:01.129000Z True

# %% [markdown]
# ## Use of Temporal Scope

# %% [markdown]
# The legacy events API design made it imperative to query events API at least twice to get the entire picture in regards to active and events that are resolved in a given time frame.
# <br>
#
# To improve this behavior in retrieving all events at the same time, we introduced the attribute **temporal_scope**.
#
#
# Any time the **start_time** and **end_time** are **non-null** values, the endpoint would only return events raised and cleared in thet time frame. To also or only retrieve events standing (currently active) in that duration, the *temporal_scope* attribute can be used.
#
# The allowed values are:
# - **include_standing**: When **start_time** and **end_time** are **non-null** values, and temporal_scope is set to include_standing, the API endpoint will include alarms **currently standing** that were raised in between the time period mentioned in the request and also alarms **raised and cleared**.
#
#
# - **standing_only**: When **start_time** and **end_time** are **non-null** values, and temporal_scope is set to standing_only, the API endpoint will return **alarms currently standing only** that were raised in between the time period mentioned in the request.

# %% [markdown]
# ### temporal_scope: include_standing

# %%
data = {
    "limit":{
        "count":100,
        "sort_on":"time",
        "sort_order":"descending"
    },
    "query":{
        "type":["alarm"],
        "site": [],
        "category":[],
        "code":[],
        "correlation_id": []
    },
    "start_time": "2023-12-07T09:05:00Z",
    "end_time": None,
    "severity":[],
    "priority":[],
    "acknowledged":False,
    "suppressed":False,
    "temporal_scope": "include_standing"
}

resp = sdk.post.events_query(data=data)
print("*******************\n{}\n*******************\n\n".format(resp.cgx_content.get("total_count")))
prisma_sase.jd_detailed(resp)
# Out:
# *******************
# 902
# *******************
#
#
# REQUEST: POST /sdwan/v3.6/api/events/query
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: */*
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....ggcBBMqPPMBrnn9WOta8uYdKulHYLm4TzvC2NEa8TixpUVTxNxAGSh42VdeQP5mAK3cpZiMmgeyerPtFngoTGIwXXdyOf0sar02IMFa_ov34vB876lHOX62Q-0HI06FiSvHjllacFuuqiGCzybG1EWkcUYsnDr7YoHv8JdrVRFWapAU1oPJTW0zyLR3TUpyk2CcWcZLzfQhju1ptM-iuCmVLkNjX-KfvXfI-bOcv72YuC0JjJVZib9mdOYiJrDpd-EmSBtUdOsFDl1fAIKJrSBSUw2m5nSiPhFqpDfhHYjuSpgrRoZ7m26-leT5VwtTuO8Lh5JFrcd6WcZGn9K6gZw
# 	Content-Type: application/json
# 	Content-Length: 334
# REQUEST BODY:
# {
#     "limit": {
#         "count": 100,
#         "sort_on": "time",
#         "sort_order": "descending"
#     },
#     "query": {
#         "type": [
#             "alarm"
#         ],
#         "site": [],
#         "category": [],
#         "code": [],
#         "correlation_id": []
#     },
#     "start_time": "2023-12-07T09:05:00Z",
#     "end_time": null,
#     "severity": [],
#     "priority": [],
#     "acknowledged": false,
#     "suppressed": false,
#     "temporal_scope": "include_standing"
# }
#
# RESPONSE: 200 OK
# RESPONSE HEADERS:
# 	date: Thu, 07 Dec 2023 14:16:25 GMT
# 	content-type: application/json
# 	Content-Length: 91513
# 	x-frame-options: SAMEORIGIN, SAMEORIGIN
# 	x-content-type-options: nosniff
# 	x-xss-protection: 1; mode=block
# 	content-security-policy: default-src 'self'
# 	cache-control: no-store, no-cache
# 	pragma: no-cache
# 	expires: 0
# 	access-control-allow-origin:
# 	access-control-allow-headers: origin, x-requested-with, accept, content-type, authorization, x-tsg-id, x-panw-region, x-sig
# 	access-control-max-age: 0
# 	access-control-allow-methods: GET, HEAD, POST, PUT, PATCH, DELETE, OPTIONS
# 	access-control-allow-credentials: true
# 	x-request-id: f2ae9a2e-13dd-4ff4-9726-ad913cb4a642
# 	Via: 1.1 google
# 	Alt-Svc: h3=":443"; ma=2592000,h3-29=":443"; ma=2592000
# RESPONSE DATA:
# {
#     "_offset": "2023-12-07T14:00:03.971000Z#6571cff7f02a3500087b5d3c",
#     "_status_code": 200,
#     "dest_page": null,
#     "included_count": 100,
#     "items": [
#         {
#             "_created_on_utc": "2023-12-07T14:15:44.745000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:15:44.745000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510433188024496",
#             "id": "6571d3906630580008dbe0e9",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:15:44.581000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:15:44.745000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:15:44.745000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691604010379021996",
#             "id": "6571d3906630580008dbe0e8",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:15:01.135000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:15:00.793000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:15:00.793000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510435419025296",
#             "id": "6571d364e0547e000891544f",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:15:00.699000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:15:00.793000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:15:00.793000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510433188024496",
#             "id": "6571d364e0547e000891544e",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:15:00.524000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:15:00.793000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:15:00.793000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691604010379021996",
#             "id": "6571d364e0547e000891544d",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:14:03.506000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:15:00.793000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:15:00.793000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510435419025296",
#             "id": "6571d364e0547e000891544c",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:14:02.973000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:14:02.836000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:14:02.836000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510433188024496",
#             "id": "6571d32af02a3500087d355f",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:14:02.726000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:13:01.019000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:13:01.019000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "C9IORnbZ",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1682433035160016296",
#             "id": "6571d2ed6630580008db7c44",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1668726451003022996",
#                         "site_id": "1668726006882012496",
#                         "timestamp": "Thu, 07 Dec 2023 14:12:50 GMT",
#                         "vep_id": "1682433404208001196",
#                         "vpnlink_id": "1682433404208001396"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1668726451003022996",
#                         "site_id": "1668726006882012496",
#                         "timestamp": "Thu, 07 Dec 2023 14:12:50 GMT",
#                         "vep_id": "1682433404208001196",
#                         "vpnlink_id": "1682433404208001396"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1682433404208001396"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1682432863194015696",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:12:52.815000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:13:01.001000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:13:01.001000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "zx1xftqX",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1682433035160016296",
#             "id": "6571d2ed6630580008db7c41",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1682432863652011096",
#                         "site_id": "1682432863194015696",
#                         "timestamp": "Thu, 07 Dec 2023 14:12:50 GMT",
#                         "vep_id": "1682433404208001096",
#                         "vpnlink_id": "1682433404208001396"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1682432863652011096",
#                         "site_id": "1682432863194015696",
#                         "timestamp": "Thu, 07 Dec 2023 14:12:50 GMT",
#                         "vep_id": "1682433404208001096",
#                         "vpnlink_id": "1682433404208001396"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1682433404208001396"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1682432863194015696",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:12:51.317000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:13:00.990000Z",
#             "_etag": 2,
#             "_updated_on_utc": "2023-12-07T14:13:00.999000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "zx1xftqX",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1682433035160016296",
#             "id": "6571d2ec6630580008db7c40",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1682432863652011096",
#                         "site_id": "1682432863194015696",
#                         "timestamp": "Thu, 07 Dec 2023 14:12:50 GMT",
#                         "vep_id": "1682433404208001096",
#                         "vpnlink_id": "1682433404208001396"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1682432863652011096",
#                         "site_id": "1682432863194015696",
#                         "timestamp": "Thu, 07 Dec 2023 14:12:50 GMT",
#                         "vep_id": "1682433404208001096",
#                         "vpnlink_id": "1682433404208001396"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1682433404208001396"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-12-07T14:13:00.989000Z",
#                 "policyrule_id": "1667225543475011896",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1682432863194015696",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:12:50.495000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:13:01.012000Z",
#             "_etag": 2,
#             "_updated_on_utc": "2023-12-07T14:13:01.017000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "C9IORnbZ",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1682433035160016296",
#             "id": "6571d2ed6630580008db7c43",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1668726451003022996",
#                         "site_id": "1668726006882012496",
#                         "timestamp": "Thu, 07 Dec 2023 14:12:50 GMT",
#                         "vep_id": "1682433404208001196",
#                         "vpnlink_id": "1682433404208001396"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1668726451003022996",
#                         "site_id": "1668726006882012496",
#                         "timestamp": "Thu, 07 Dec 2023 14:12:50 GMT",
#                         "vep_id": "1682433404208001196",
#                         "vpnlink_id": "1682433404208001396"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1682433404208001396"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-12-07T14:13:01.011000Z",
#                 "policyrule_id": "1667225543475011896",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1682432863194015696",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:12:50.477000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:11:01.681000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:11:01.681000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "FLAP_RATE_EXCEEDED",
#             "correlation_id": "HUhKIvpq",
#             "element_cluster_roles": [
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/sites/1665769628075005096",
#             "id": "6571d2750f93700007318427",
#             "info": null,
#             "notes": null,
#             "policy_info": {
#                 "code": "SITE_CONNECTIVITY_DEGRADED",
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p3",
#             "severity": "major",
#             "site_id": "1665769628075005096",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:11:01.681000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:13:00.973000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:13:00.973000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "KG1tE79r",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1690215029256019496",
#             "id": "6571d2ec6630580008db7c3e",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:10:30 GMT",
#                         "vep_id": "1691183510765017496",
#                         "vpnlink_id": "1691183510765017696"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:10:30 GMT",
#                         "vep_id": "1691183510765017496",
#                         "vpnlink_id": "1691183510765017696"
#                     },
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1691174559689008796",
#                         "site_id": "1690215028416010696",
#                         "timestamp": "Thu, 07 Dec 2023 14:10:30 GMT",
#                         "vep_id": "1691183510765017396",
#                         "vpnlink_id": "1691183510765017696"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1691174559689008796",
#                         "site_id": "1690215028416010696",
#                         "timestamp": "Thu, 07 Dec 2023 14:10:30 GMT",
#                         "vep_id": "1691183510765017396",
#                         "vpnlink_id": "1691183510765017696"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1691183510765017696"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1690215028416010696",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:10:32.222000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:10:31.411000Z",
#             "_etag": 2,
#             "_updated_on_utc": "2023-12-07T14:13:00.969000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "KG1tE79r",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1690215029256019496",
#             "id": "6571d257f02a3500087cc677",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:10:30 GMT",
#                         "vep_id": "1691183510765017496",
#                         "vpnlink_id": "1691183510765017696"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:10:30 GMT",
#                         "vep_id": "1691183510765017496",
#                         "vpnlink_id": "1691183510765017696"
#                     },
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1691174559689008796",
#                         "site_id": "1690215028416010696",
#                         "timestamp": "Thu, 07 Dec 2023 14:10:30 GMT",
#                         "vep_id": "1691183510765017396",
#                         "vpnlink_id": "1691183510765017696"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1691174559689008796",
#                         "site_id": "1690215028416010696",
#                         "timestamp": "Thu, 07 Dec 2023 14:10:30 GMT",
#                         "vep_id": "1691183510765017396",
#                         "vpnlink_id": "1691183510765017696"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1691183510765017696"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-12-07T14:10:31.409000Z",
#                 "policyrule_id": "1667225543475011896",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1690215028416010696",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:10:30.110000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:09:00.909000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:09:00.909000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "SITE_CONNECTIVITY_DEGRADED",
#             "correlation_id": "McvJZerR",
#             "element_cluster_roles": [
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/sites/1663699016854013396",
#             "id": "6571d1fce0547e000890b3a6",
#             "info": null,
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-12-07T14:09:00.843000Z",
#                 "policyrule_id": "1667225629509006796",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p3",
#             "severity": "major",
#             "site_id": "1663699016854013396",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:08:21.877000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:09:00.910000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:09:00.910000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "SITE_CONNECTIVITY_DEGRADED",
#             "correlation_id": "8TKfdY7m",
#             "element_cluster_roles": [
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/sites/1668726006882012496",
#             "id": "6571d1fce0547e000890b3a7",
#             "info": null,
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-12-07T14:09:00.843000Z",
#                 "policyrule_id": "1667225629509006796",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p3",
#             "severity": "major",
#             "site_id": "1668726006882012496",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:08:21.877000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:09:00.869000Z",
#             "_etag": 4,
#             "_updated_on_utc": "2023-12-07T14:09:00.912000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "NETWORK_ANYNETLINK_DOWN",
#             "correlation_id": "iiCFa6bj",
#             "element_cluster_roles": [
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1682512097246021496",
#             "id": "6571d1fce0547e000890b39e",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:19 GMT",
#                         "vep_id": "1682512097955018796",
#                         "vpnlink_id": "1682512097955018996"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:19 GMT",
#                         "vep_id": "1682512097955018796",
#                         "vpnlink_id": "1682512097955018996"
#                     },
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1668726451003022996",
#                         "site_id": "1668726006882012496",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:20 GMT",
#                         "vep_id": "1682512097955018696",
#                         "vpnlink_id": "1682512097955018996"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1668726451003022996",
#                         "site_id": "1668726006882012496",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:20 GMT",
#                         "vep_id": "1682512097955018696",
#                         "vpnlink_id": "1682512097955018996"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1682512097955018996"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-12-07T14:09:00.867000Z",
#                 "policyrule_id": "1667225543475011896",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p2",
#             "severity": "major",
#             "site_id": "1668726006882012496",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:08:19.634000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:09:00.821000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:09:00.821000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "VHrdW2UW",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1663699017546012396",
#             "id": "6571d1fce0547e000890b37b",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:12 GMT",
#                         "vep_id": "1679333502225012696",
#                         "vpnlink_id": "1679333502225012996"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:12 GMT",
#                         "vep_id": "1679333502225012696",
#                         "vpnlink_id": "1679333502225012996"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1679333502225012996"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1663699016854013396",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:08:13.907000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:08:13.984000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:08:13.984000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "uQXPtVAd",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1663699017546012396",
#             "id": "6571d1cde0547e000890981c",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1663700128668003096",
#                         "site_id": "1663698905066012396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:12 GMT",
#                         "vep_id": "1679333502225012796",
#                         "vpnlink_id": "1679333502225012996"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1663700128668003096",
#                         "site_id": "1663698905066012396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:12 GMT",
#                         "vep_id": "1679333502225012796",
#                         "vpnlink_id": "1679333502225012996"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1679333502225012996"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1663699016854013396",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:08:13.588000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:08:13.970000Z",
#             "_etag": 2,
#             "_updated_on_utc": "2023-12-07T14:08:13.982000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "uQXPtVAd",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1663699017546012396",
#             "id": "6571d1cde0547e000890981b",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1663700128668003096",
#                         "site_id": "1663698905066012396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:12 GMT",
#                         "vep_id": "1679333502225012796",
#                         "vpnlink_id": "1679333502225012996"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1663700128668003096",
#                         "site_id": "1663698905066012396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:12 GMT",
#                         "vep_id": "1679333502225012796",
#                         "vpnlink_id": "1679333502225012996"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1679333502225012996"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-12-07T14:08:13.967000Z",
#                 "policyrule_id": "1667225543475011896",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1663699016854013396",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:08:12.664000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:08:14.189000Z",
#             "_etag": 2,
#             "_updated_on_utc": "2023-12-07T14:09:00.819000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "NETWORK_ANYNETLINK_DEGRADED",
#             "correlation_id": "VHrdW2UW",
#             "element_cluster_roles": [
#                 "HUB",
#                 "SPOKE"
#             ],
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1663699017546012396",
#             "id": "6571d1cef02a3500087c72e2",
#             "info": {
#                 "vpn_reasons": [
#                     {
#                         "code": "NETWORK_VPNLINK_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:12 GMT",
#                         "vep_id": "1679333502225012696",
#                         "vpnlink_id": "1679333502225012996"
#                     },
#                     {
#                         "code": "NETWORK_VPNBFD_DOWN",
#                         "element_id": "1679333011928014596",
#                         "site_id": "1663699016854013396",
#                         "timestamp": "Thu, 07 Dec 2023 14:08:12 GMT",
#                         "vep_id": "1679333502225012696",
#                         "vpnlink_id": "1679333502225012996"
#                     }
#                 ],
#                 "vpnlinks": [
#                     "1679333502225012996"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-12-07T14:08:14.179000Z",
#                 "policyrule_id": "1667225543475011896",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p2",
#             "severity": "minor",
#             "site_id": "1663699016854013396",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:08:12.625000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:06:42.236000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:06:42.236000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "DEVICEHW_INTERFACE_DOWN",
#             "correlation_id": "JyzXpb7C",
#             "element_cluster_roles": [
#                 "PA_CONN"
#             ],
#             "element_id": "1683571676743006596",
#             "entity_ref": "tenants/1228584868/sites/1683571675856024596/elements/1683571676743006596/interfaces/1683571859182014796",
#             "id": "6571d172f02a3500087c43f5",
#             "info": {
#                 "circuit_labels": "",
#                 "extended_state": "tunnel_down",
#                 "name": "ipsec",
#                 "parent_interface": "1",
#                 "reason": "down",
#                 "remote_hostname": "",
#                 "remote_ip": "134.238.192.76"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p3",
#             "severity": "major",
#             "site_id": "1683571675856024596",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:06:40.532000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:06:42.222000Z",
#             "_etag": 2,
#             "_updated_on_utc": "2023-12-07T14:06:42.234000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "DEVICEHW_INTERFACE_DOWN",
#             "correlation_id": "JyzXpb7C",
#             "element_cluster_roles": [
#                 "PA_CONN"
#             ],
#             "element_id": "1683571676743006596",
#             "entity_ref": "tenants/1228584868/sites/1683571675856024596/elements/1683571676743006596/interfaces/1683571859182014796",
#             "id": "6571d172f02a3500087c43f4",
#             "info": {
#                 "circuit_labels": "",
#                 "extended_state": "tunnel_down",
#                 "name": "ipsec",
#                 "parent_interface": "1",
#                 "reason": "down",
#                 "remote_hostname": "",
#                 "remote_ip": "134.238.192.76"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-12-07T14:06:42.222000Z",
#                 "policyrule_id": null,
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p3",
#             "severity": "major",
#             "site_id": "1683571675856024596",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:06:34.995000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:06:32.974000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:06:32.974000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "DEVICEHW_INTERFACE_DOWN",
#             "correlation_id": "7N4ozdB0",
#             "element_cluster_roles": [
#                 "PA_CONN"
#             ],
#             "element_id": "1683573651875020596",
#             "entity_ref": "tenants/1228584868/sites/1683573650422018696/elements/1683573651875020596/interfaces/1683573834770022996",
#             "id": "6571d1686630580008dad362",
#             "info": {
#                 "circuit_labels": "",
#                 "extended_state": "tunnel_down",
#                 "name": "ipsec",
#                 "parent_interface": "1",
#                 "reason": "down",
#                 "remote_hostname": "",
#                 "remote_ip": "134.238.233.113"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p3",
#             "severity": "major",
#             "site_id": "1683573650422018696",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:06:29.844000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:06:32.935000Z",
#             "_etag": 1,
# ...
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:11.003000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510433188024496",
#             "id": "6571cff7f02a3500087b5d47",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:10.827000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691604010379021996",
#             "id": "6571cff7f02a3500087b5d46",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:07.787000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510435419025296",
#             "id": "6571cff7f02a3500087b5d45",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:07.373000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510433188024496",
#             "id": "6571cff7f02a3500087b5d44",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:07.161000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691604010379021996",
#             "id": "6571cff7f02a3500087b5d43",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:06.423000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510435419025296",
#             "id": "6571cff7f02a3500087b5d42",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:05.951000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510433188024496",
#             "id": "6571cff7f02a3500087b5d41",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:05.781000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691604010379021996",
#             "id": "6571cff7f02a3500087b5d40",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:05.444000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510435419025296",
#             "id": "6571cff7f02a3500087b5d3f",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:05Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510433188024496",
#             "id": "6571cff7f02a3500087b5d3e",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:04.816000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691604010379021996",
#             "id": "6571cff7f02a3500087b5d3d",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:04.453000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-12-07T14:00:23.627000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-12-07T14:00:23.627000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": true,
#             "code": "USER_ID_DIRECTORY_SYNC_FAILED",
#             "correlation_id": null,
#             "element_cluster_roles": null,
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/directoryservices/1682464928449004096/domainstatus/1691510435419025296",
#             "id": "6571cff7f02a3500087b5d3c",
#             "info": {
#                 "reason": "Sync failed for directory"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": null,
#                 "policyrule_id": null,
#                 "policyset_id": null
#             },
#             "priority": "p4",
#             "severity": "minor",
#             "standing": false,
#             "suppressed": false,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": null,
#                 "suppressed_time": null
#             },
#             "time": "2023-12-07T14:00:03.971000Z",
#             "type": "alarm"
#         }
#     ],
#     "total_count": 902
# }

# %% [markdown]
# ### temporal_scope: standing_only

# %%
data = {
    "limit":{
        "count":100,
        "sort_on":"time",
        "sort_order":"descending"
    },
    "query":{
        "type":["alarm"],
        "site": [],
        "category":[],
        "code":[],
        "correlation_id": []
    },
    "start_time": "2023-12-01T00:00:00Z",
    "end_time": None,
    "severity":[],
    "priority":[],
    "acknowledged":False,
    "suppressed":False,
    "temporal_scope": "standing_only"
}

resp = sdk.post.events_query(data=data)
print("*******************\n{}\n*******************\n\n".format(resp.cgx_content.get("total_count")))
#prisma_sase.jd_detailed(resp)
events = resp.cgx_content.get("items", None)
for event in events:
    print(event["time"], event["cleared"])
# Out:
# *******************
# 6
# *******************
#
#
# 2023-12-07T13:54:10.327000Z False
# 2023-12-07T13:52:23.298000Z False
# 2023-12-07T13:50:32.139000Z False
# 2023-12-07T08:49:15.869000Z False
# 2023-12-06T20:22:32.153000Z False
# 2023-12-06T19:33:39.952000Z False

# %% [markdown]
# ## Retrieve Related Faults - Summary Events

# %%
data ={
    "severity":[],
    "suppressed_info":{
        "summary_event_ids":["649de3c48e1b8100085ae594"]
    }
}

resp = sdk.post.events_query(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/v3.5/api/events/query
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1 (PRISMA SASE SDK v6.1.2b1)
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: application/json
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....ReRAM4rkhzUkyrWy-PADUZpTBbH28TBl0g6GGfR9oRWBfwG0o0tLq2TtZZNUwmbjmdi1SZ5kBO__n_9nW__0W0FmFzLLYEcYvKK7kJ2NVoneLAER95A6wV_bjYNkYO9sy0HuK3h3qX8soVoWGXVaySk1Oqd7GC6v9-9dM8eB-efWLcDvW8W_5OEWb2o3f6IEQqauQej7IrxBK-JXYB6vdsn9NIU-vmFgITTp489h73WSb-MDsI3CItfg0EfsImtUHgkpE0pkIvOJW8tFOthkGWmb7IUZdTXYlRjH1aJGsMq6OV_Fv_2HZc_slb1-KBlCzt8O0ThJoStEbOrd-5IZpw
# 	X-PANW-Region: americas
# 	Content-Type: application/json
# 	Content-Length: 88
# REQUEST BODY:
# {
#     "severity": [],
#     "suppressed_info": {
#         "summary_event_ids": [
#             "649de3c48e1b8100085ae594"
#         ]
#     }
# }
#
# RESPONSE: 200 OK
# RESPONSE HEADERS:
# 	date: Thu, 06 Jul 2023 12:37:35 GMT
# 	content-type: application/json
# 	content-length: 1144
# 	x-frame-options: SAMEORIGIN, SAMEORIGIN
# 	x-content-type-options: nosniff
# 	x-xss-protection: 1; mode=block
# 	content-security-policy: default-src 'self'
# 	cache-control: no-store, no-cache
# 	pragma: no-cache
# 	expires: 0
# 	access-control-allow-origin:
# 	access-control-allow-headers: origin, x-requested-with, accept, content-type, authorization, x-tsg-id, x-panw-region
# 	access-control-max-age: 0
# 	access-control-allow-methods: GET, HEAD, POST, PUT, PATCH, DELETE, OPTIONS
# 	access-control-allow-credentials: true
# 	x-request-id: e34dce28-81c0-41b5-99f7-63db87348201
# 	Via: 1.1 google
# 	Alt-Svc: h3=":443"; ma=2592000,h3-29=":443"; ma=2592000
# RESPONSE DATA:
# {
#     "_offset": null,
#     "_status_code": 200,
#     "included_count": 1,
#     "items": [
#         {
#             "_created_on_utc": "2023-06-29T20:04:20.065000Z",
#             "_etag": 1,
#             "_updated_on_utc": "2023-06-29T20:04:20.065000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "DEVICEHW_INTERFACE_DOWN",
#             "correlation_id": "i8p1BdUE",
#             "element_id": "1679333011928014596",
#             "entity_ref": "tenants/1228584868/sites/1663699016854013396/elements/1679333011928014596/interfaces/1686747610110018596",
#             "id": "649de3c48e1b8100085ae595",
#             "info": {
#                 "circuit_labels": "Verizon Internet",
#                 "extended_state": "config_changed",
#                 "name": "Test-Tun",
#                 "parent_interface": "1",
#                 "reason": "down",
#                 "remote_hostname": "www.bbc.com",
#                 "remote_ip": "151.101.0.81"
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-06-29T20:04:20.065000Z",
#                 "policyrule_id": null,
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p3",
#             "severity": "major",
#             "site_id": "1663699016854013396",
#             "standing": true,
#             "suppressed": true,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": [
#                     "649de3c48e1b8100085ae594"
#                 ],
#                 "suppressed_time": "2023-06-29T20:04:20.062000Z"
#             },
#             "time": "2023-06-29T20:04:09.479000Z",
#             "type": "alarm"
#         }
#     ],
#     "total_count": 1
# }

# %% [markdown]
# ## Retrieve Faults Suppressed due to Policy

# %%
data ={
    "severity":[],
    "policy_info":{
        "policyrule_id":["1667225543475011896"]
    }
}

resp = sdk.post.events_query(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/v3.5/api/events/query
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1 (PRISMA SASE SDK v6.1.2b1)
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: application/json
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....ReRAM4rkhzUkyrWy-PADUZpTBbH28TBl0g6GGfR9oRWBfwG0o0tLq2TtZZNUwmbjmdi1SZ5kBO__n_9nW__0W0FmFzLLYEcYvKK7kJ2NVoneLAER95A6wV_bjYNkYO9sy0HuK3h3qX8soVoWGXVaySk1Oqd7GC6v9-9dM8eB-efWLcDvW8W_5OEWb2o3f6IEQqauQej7IrxBK-JXYB6vdsn9NIU-vmFgITTp489h73WSb-MDsI3CItfg0EfsImtUHgkpE0pkIvOJW8tFOthkGWmb7IUZdTXYlRjH1aJGsMq6OV_Fv_2HZc_slb1-KBlCzt8O0ThJoStEbOrd-5IZpw
# 	X-PANW-Region: americas
# 	Content-Type: application/json
# 	Content-Length: 75
# REQUEST BODY:
# {
#     "severity": [],
#     "policy_info": {
#         "policyrule_id": [
#             "1667225543475011896"
#         ]
#     }
# }
#
# RESPONSE: 200 OK
# RESPONSE HEADERS:
# 	date: Thu, 06 Jul 2023 12:38:02 GMT
# 	content-type: application/json
# 	content-length: 1840
# 	x-frame-options: SAMEORIGIN, SAMEORIGIN
# 	x-content-type-options: nosniff
# 	x-xss-protection: 1; mode=block
# 	content-security-policy: default-src 'self'
# 	cache-control: no-store, no-cache
# 	pragma: no-cache
# 	expires: 0
# 	access-control-allow-origin:
# 	access-control-allow-headers: origin, x-requested-with, accept, content-type, authorization, x-tsg-id, x-panw-region
# 	access-control-max-age: 0
# 	access-control-allow-methods: GET, HEAD, POST, PUT, PATCH, DELETE, OPTIONS
# 	access-control-allow-credentials: true
# 	x-request-id: 0bb41b60-6a2b-46d8-b6ab-99ab6259223c
# 	Via: 1.1 google
# 	Alt-Svc: h3=":443"; ma=2592000,h3-29=":443"; ma=2592000
# RESPONSE DATA:
# {
#     "_offset": null,
#     "_status_code": 200,
#     "included_count": 2,
#     "items": [
#         {
#             "_created_on_utc": "2023-06-20T02:16:40.772000Z",
#             "_etag": 14,
#             "_updated_on_utc": "2023-06-29T23:46:15.108000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "NETWORK_ANYNETLINK_DOWN",
#             "correlation_id": "yx7x76OX",
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1687226556425020696",
#             "id": "64910c088e1b8100089c94a8",
#             "info": {
#                 "vpnlinks": [
#                     "1687227367064018696",
#                     "1687227366949017596"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-06-20T02:22:00.390000Z",
#                 "policyrule_id": "1667225543475011896",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p1",
#             "severity": "major",
#             "site_id": "1687226555353012596",
#             "standing": true,
#             "suppressed": true,
#             "suppressed_info": {
#                 "event_ids": [],
#                 "other_reasons": null,
#                 "summary_event_ids": [
#                     "6494ffd3f9fead000778e3ea"
#                 ],
#                 "suppressed_time": "2023-06-29T23:46:15.056000Z"
#             },
#             "time": "2023-06-20T02:16:37.215000Z",
#             "type": "alarm"
#         },
#         {
#             "_created_on_utc": "2023-06-13T02:53:43.167000Z",
#             "_etag": 2,
#             "_updated_on_utc": "2023-06-13T02:53:43.167000Z",
#             "acknowledged": false,
#             "acknowledgement_info": null,
#             "cleared": false,
#             "code": "NETWORK_ANYNETLINK_DOWN",
#             "correlation_id": "TGV6oKcA",
#             "element_id": null,
#             "entity_ref": "tenants/1228584868/anynetlinks/1686624753082025296",
#             "id": "6487da37f9fead000790ca18",
#             "info": {
#                 "vpnlinks": [
#                     "1686624791474017696",
#                     "1686624791581018796"
#                 ]
#             },
#             "notes": null,
#             "policy_info": {
#                 "policy_applied_time": "2023-06-13T02:59:01.689000Z",
#                 "policyrule_id": "1667225543475011896",
#                 "policyset_id": "1667225282294023396"
#             },
#             "priority": "p1",
#             "severity": "major",
#             "site_id": "1686624752147006896",
#             "standing": true,
#             "suppressed": true,
#             "suppressed_info": {
#                 "event_ids": null,
#                 "other_reasons": null,
#                 "summary_event_ids": [
#                     "6487da37f9fead000790ca16"
#                 ],
#                 "suppressed_time": "2023-06-13T02:53:43.155000Z"
#             },
#             "time": "2023-06-13T02:53:41.791000Z",
#             "type": "alarm"
#         }
#     ],
#     "total_count": 2
# }
