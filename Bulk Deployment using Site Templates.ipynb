# %%
###############################
# Import SDK & Libraries
###############################

import prisma_sase
import time

# %%
###############################
# Service Account Details
###############################

client_id = "paste client ID"
client_secret = "paste client secret"
tsg_id = "paste TSG ID"

# %%
##############################################################
# Instantiate SDK & login using service account
##############################################################

sase_session = prisma_sase.API()
sase_session.interactive.login_secret(client_id=client_id, client_secret=client_secret, tsg_id=tsg_id)
# Out:
# WARNING: Prisma SASE Python SDK upgrade available. SDKs are often deprecated 6 months after release of a new version.
# 	Latest Version: 6.3.2b1
# 	Current Version: 6.3.1b1
# 	For more info, see 'https://github.com/PaloAltoNetworks/prisma-sase-sdk-python'. Additionally, this message can be suppressed by instantiating the API with API(update_check=False).
# True

# %%
###############################
# Create Site Dictionary
###############################

site_id_name = {}
site_name_id = {}

#
# Site ID to be used for template creation
#
SITE_ID = None

resp = sase_session.get.sites()
if resp.cgx_status:
    sitelist = resp.cgx_content.get("items", None)
    for site in sitelist:
        site_id_name[site["id"]] = site["name"]
        site_name_id[site["name"]] = site["id"]
        
        if site["name"] == "Branch 1 - Raleigh":
            SITE_ID = site["id"]
            
else:
    print("ERR: Could not retrieve Sites")
    prisma_sase.jd_detailed(resp)
        
        
if SITE_ID is None:
    print("ERR: Site not found!!")

# %%
###############################
# Create Site Template
###############################

TEMPLATE_ID = None
data = {
    "site_id":SITE_ID,
    "site_type":"SPOKE",
    "template_name":"template_name",
    "template_description":"template_description"
}

resp = sase_session.post.bulkconfigurations_sitetemplates(data=data)
if resp.cgx_status:
    TEMPLATE_ID = resp.cgx_content.get("id", None)
    print("Site Template Create Request Sent. Site Template ID: {}".format(TEMPLATE_ID))
else:
    print("ERR: Could not send Site Template Create Request")
    prisma_sase.jd_detailed(resp)
# Out:
# Site Template Create Request Sent. Site Template ID: 1715361469108000196

# %%
###############################
# Check Site Template Status
###############################

created = False
while not created:
    resp = sase_session.get.bulkconfigurations_sitetemplates_status(sitetemplate_id=TEMPLATE_ID)
    if resp.cgx_status:
        status = resp.cgx_content.get("status", None)
        status_desc = resp.cgx_content.get("status_description", None)
        
        print("{} [{}]".format(status, status_desc))
        if status == "SUCCESS":
            created = True
        else:
            print("Sleeping 2 seconds..")
            time.sleep(2)
        
            
    else:
        print("ERR: Could not retrieve status")
        prisma_sase.jd_detailed(resp)
        print("Sleeping 2 seconds..")
        time.sleep(2)
# Out:
# INIT [INIT]
# Sleeping 2 seconds..
# INIT [INIT]
# Sleeping 2 seconds..
# INIT [INIT]
# Sleeping 2 seconds..
# SUCCESS [Template created successfully.]

# %%
##############################################
# GET Sites Template & Variable Map
##############################################
resp = sase_session.get.bulkconfigurations_sitetemplates(sitetemplate_id=TEMPLATE_ID)
if resp.cgx_status:
    variable_map = resp.cgx_content.get("variable_map", None)
    print("Variable Map: ")
    prisma_sase.jd_detailed(variable_map)
# Out:
# Variable Map:
# {
#     "site_name": "Branch 1 - Raleigh",
#     "street": "316 Faynetteville St.",
#     "ion_sw_version": "6.2.2-b1",
#     "ion_name_1": "device-1",
#     "ion_serial_number_1": "4229b40f-2a39-7947-3a0b-3a6e99591238"
# }

# %%
###############################################
# Deploy using Site Template
###############################################
data = {
    "variable_map":[
        {
            "site_name":"test-tk1",
            "street":"123 main st",
            "ion_sw_version":"6.2.2-b1",
            "ion_name_1":"test-tk1-ion",
            "ion_serial_number_1":""
        },
        {
            "site_name":"test-tk2",
            "street":"123 main st",
            "ion_sw_version":"6.2.2-b1",
            "ion_name_1":"test-tk2-ion",
            "ion_serial_number_1":""
        },
        {
            "site_name":"test-tk3",
            "street":"123 main st",
            "ion_sw_version":"6.2.2-b1",
            "ion_name_1":"test-tk3-ion",
            "ion_serial_number_1":""
        }
    ]
}

JOB_IDS = []
jobid_sitename = {}
resp = sase_session.post.bulkconfigurations_sitetemplates_deployments(sitetemplate_id=TEMPLATE_ID, data=data)
if resp.cgx_status:
    deployments = resp.cgx_content.get("items", None)
    for deployjob in deployments:
        sitename = deployjob.get("variable_map", None)["site_name"]
        jobid = deployjob.get("deployment_id", None)
        jobid_sitename[jobid] = sitename
        
        print("Job created for {} [{}]".format(sitename, jobid))
        JOB_IDS.append(jobid)

        
else:
    print("ERR: Could not create deployment jobs")
    prisma_sase.jd_detailed(resp)
# Out:
# Job created for test-tk1 [1715364855762018096]
# Job created for test-tk2 [1715364855870018596]
# Job created for test-tk3 [1715364855973019096]

# %%
##############################################################
# Get Deployment Status using deployment ID
##############################################################

for jobid in JOB_IDS:
    print("**************************")
    print("Site: {} Job: {}".format(jobid_sitename[jobid], jobid))

    status = "INIT"
    while status != "SUCCESS":
        url = "https://api.sase.paloaltonetworks.com/sdwan/v2.0/api/bulkconfigurations/sitetemplates/{}/deployments/{}/status".format(TEMPLATE_ID, jobid)
        resp = sase_session.rest_call(method="GET", url=url)
        if resp.cgx_status:
            status = resp.cgx_content.get("status", None)
            status_description = resp.cgx_content.get("status_description", None)
            print("\tStatus:{} [{}]".format(status, status_description))
            
            if status != "SUCCESS":
                print("\tDeployment ongoing. Sleeping 2 seconds..")
                time.sleep(2)
                
            else:
                print("\tDeployment Complete!!")
                

        else:
            print("ERR: Could not retrieve deployment status")
            prisma_sase.jd_detailed(resp)
# Out:
# **************************
# Site: test-tk1 Job: 1715364855762018096
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:SUCCESS [Successfully deployed site 'test-tk1]
# 	Deployment Complete!!
# **************************
# Site: test-tk2 Job: 1715364855870018596
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:SUCCESS [Successfully deployed site 'test-tk2]
# 	Deployment Complete!!
# **************************
# Site: test-tk3 Job: 1715364855973019096
# 	Status:INIT [INIT]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:INPROGRESS [INPROGRESS]
# 	Deployment ongoing. Sleeping 2 seconds..
# 	Status:SUCCESS [Successfully deployed site 'test-tk3]
# 	Deployment Complete!!

# %%
##############################################################
# Query API for all Deployments
##############################################################

data = {
    "query_params":{},
    "limit":10,
    "dest_page":1,
    "sort_params":{"_updated_on_utc":"desc"},
    "retrieved_fields":[],
    "retrieved_fields_mask":True
}


resp = sase_session.rest_call(method="POST", 
                     data=data,
                     url="https://api.sase.paloaltonetworks.com/sdwan/v2.0/api/bulkconfigurations/sitetemplates/deployments/query")
prisma_sase.jd_detailed(resp.cgx_content)
# Out:
# {
#     "_etag": 0,
#     "_content_length": "0",
#     "_schema": 0,
#     "_created_on_utc": 0,
#     "_updated_on_utc": 0,
#     "_status_code": "200",
#     "_request_id": "1715364959016017199995733041024699950510",
#     "count": 10,
#     "items": [
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17153648558700185,
#             "_updated_on_utc": 17153648939710052,
#             "variable_map": {
#                 "site_name": "test-tk2",
#                 "street": "123 main st",
#                 "ion_sw_version": "6.2.2-b1",
#                 "ion_name_1": "test-tk2-ion",
#                 "ion_serial_number_1": ""
#             },
#             "deployment_id": "1715364855870018596",
#             "template_id": "1715361469108000196",
#             "site_id": "1715364867888006196",
#             "site_name": "test-tk2",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'test-tk2",
#             "template_name": "template_name",
#             "_created_by_operator_id": "1706808455741007296",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": [
#                 {
#                     "id": "17153648693510007",
#                     "_created_on_utc": 17153648693710008,
#                     "_updated_on_utc": 17153648693990009,
#                     "_debug": null,
#                     "_info": null,
#                     "_warning": null,
#                     "_error": null,
#                     "hw_id": "SHELL#1715364869371000896",
#                     "name": "test-tk2-ion",
#                     "connected": "false",
#                     "device_type": "SHELL"
#                 }
#             ]
#         },
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17153648559730190,
#             "_updated_on_utc": 17153648939540051,
#             "variable_map": {
#                 "site_name": "test-tk3",
#                 "street": "123 main st",
#                 "ion_sw_version": "6.2.2-b1",
#                 "ion_name_1": "test-tk3-ion",
#                 "ion_serial_number_1": ""
#             },
#             "deployment_id": "1715364855973019096",
#             "template_id": "1715361469108000196",
#             "site_id": "1715364878567022096",
#             "site_name": "test-tk3",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'test-tk3",
#             "template_name": "template_name",
#             "_created_by_operator_id": "1706808455741007296",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": [
#                 {
#                     "id": "17153648801810205",
#                     "_created_on_utc": 17153648801900206,
#                     "_updated_on_utc": 17153648802040207,
#                     "_debug": null,
#                     "_info": null,
#                     "_warning": null,
#                     "_error": null,
#                     "hw_id": "SHELL#1715364880190020696",
#                     "name": "test-tk3-ion",
#                     "connected": "false",
#                     "device_type": "SHELL"
#                 }
#             ]
#         },
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17153648557620180,
#             "_updated_on_utc": 17153648939380050,
#             "variable_map": {
#                 "site_name": "test-tk1",
#                 "street": "123 main st",
#                 "ion_sw_version": "6.2.2-b1",
#                 "ion_name_1": "test-tk1-ion",
#                 "ion_serial_number_1": ""
#             },
#             "deployment_id": "1715364855762018096",
#             "template_id": "1715361469108000196",
#             "site_id": "1715364858243023296",
#             "site_name": "test-tk1",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'test-tk1",
#             "template_name": "template_name",
#             "_created_by_operator_id": "1706808455741007296",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": [
#                 {
#                     "id": "17153648596290060",
#                     "_created_on_utc": 17153648596390061,
#                     "_updated_on_utc": 17153648596590062,
#                     "_debug": null,
#                     "_info": null,
#                     "_warning": null,
#                     "_error": null,
#                     "hw_id": "SHELL#1715364859639006196",
#                     "name": "test-tk1-ion",
#                     "connected": "false",
#                     "device_type": "SHELL"
#                 }
#             ]
#         },
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17153632721990190,
#             "_updated_on_utc": 17153633376320082,
#             "variable_map": {
#                 "site_name": "site3",
#                 "street": "123 main st",
#                 "ion_sw_version": "6.2.2-b1",
#                 "ion_name_1": "ion3",
#                 "ion_serial_number_1": ""
#             },
#             "deployment_id": "1715363272199019096",
#             "template_id": "1715361469108000196",
#             "site_id": "1715363301321000896",
#             "site_name": "site3",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'site3",
#             "template_name": "template_name",
#             "_created_by_operator_id": "1706805074765011896",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": [
#                 {
#                     "id": "17153633027340040",
#                     "_created_on_utc": 17153633027360041,
#                     "_updated_on_utc": 17153633027460042,
#                     "_debug": null,
#                     "_info": null,
#                     "_warning": null,
#                     "_error": null,
#                     "hw_id": "SHELL#1715363302736004196",
#                     "name": "ion3",
#                     "connected": "false",
#                     "device_type": "SHELL"
#                 }
#             ]
#         },
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17153632720540180,
#             "_updated_on_utc": 17153633072880047,
#             "variable_map": {
#                 "site_name": "site1",
#                 "street": "123 main st",
#                 "ion_sw_version": "6.2.2-b1",
#                 "ion_name_1": "ion1",
#                 "ion_serial_number_1": ""
#             },
#             "deployment_id": "1715363272054018096",
#             "template_id": "1715361469108000196",
#             "site_id": "1715363279478005396",
#             "site_name": "site1",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'site1",
#             "template_name": "template_name",
#             "_created_by_operator_id": "1706805074765011896",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": [
#                 {
#                     "id": "17153632819770215",
#                     "_created_on_utc": 17153632819900216,
#                     "_updated_on_utc": 17153632820190217,
#                     "_debug": null,
#                     "_info": null,
#                     "_warning": null,
#                     "_error": null,
#                     "hw_id": "SHELL#1715363281990021696",
#                     "name": "ion1",
#                     "connected": "false",
#                     "device_type": "SHELL"
#                 }
#             ]
#         },
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17153632721310185,
#             "_updated_on_utc": 17153633072710046,
#             "variable_map": {
#                 "site_name": "site2",
#                 "street": "123 main st",
#                 "ion_sw_version": "6.2.2-b1",
#                 "ion_name_1": "ion2",
#                 "ion_serial_number_1": ""
#             },
#             "deployment_id": "1715363272131018596",
#             "template_id": "1715361469108000196",
#             "site_id": "1715363291327019496",
#             "site_name": "site2",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'site2",
#             "template_name": "template_name",
#             "_created_by_operator_id": "1706805074765011896",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": [
#                 {
#                     "id": "17153632927180227",
#                     "_created_on_utc": 17153632927230228,
#                     "_updated_on_utc": 17153632927370229,
#                     "_debug": null,
#                     "_info": null,
#                     "_warning": null,
#                     "_error": null,
#                     "hw_id": "SHELL#1715363292723022896",
#                     "name": "ion2",
#                     "connected": "false",
#                     "device_type": "SHELL"
#                 }
#             ]
#         },
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17153628422540211,
#             "_updated_on_utc": 17153628752850169,
#             "variable_map": {
#                 "site_name": "testtk1",
#                 "street": "123 main st",
#                 "ion_sw_version": "6.2.2-b1",
#                 "ion_name_1": "testtk1-ion",
#                 "ion_serial_number_1": ""
#             },
#             "deployment_id": "1715362842254021196",
#             "template_id": "1715361469108000196",
#             "site_id": "1715362849718000996",
#             "site_name": "testtk1",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'testtk1",
#             "template_name": "template_name",
#             "_created_by_operator_id": "1706805074765011896",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": []
#         },
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17153628423360216,
#             "_updated_on_utc": 17153628752740168,
#             "variable_map": {
#                 "site_name": "testtk2",
#                 "street": "123 main st",
#                 "ion_sw_version": "6.2.2-b1",
#                 "ion_name_1": "testtk2-ion",
#                 "ion_serial_number_1": ""
#             },
#             "deployment_id": "1715362842336021696",
#             "template_id": "1715361469108000196",
#             "site_id": "1715362858922003096",
#             "site_name": "testtk2",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'testtk2",
#             "template_name": "template_name",
#             "_created_by_operator_id": "1706805074765011896",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": []
#         },
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17153628424160221,
#             "_updated_on_utc": 17153628752580167,
#             "variable_map": {
#                 "site_name": "testtk3",
#                 "street": "123 main st",
#                 "ion_sw_version": "6.2.2-b1",
#                 "ion_name_1": "testtk3-ion",
#                 "ion_serial_number_1": ""
#             },
#             "deployment_id": "1715362842416022196",
#             "template_id": "1715361469108000196",
#             "site_id": "1715362867718023596",
#             "site_name": "testtk3",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'testtk3",
#             "template_name": "template_name",
#             "_created_by_operator_id": "1706805074765011896",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": []
#         },
#         {
#             "_content_length": 0,
#             "_created_on_utc": 17111375758500228,
#             "_updated_on_utc": 17111376170130065,
#             "variable_map": {
#                 "country": "usa",
#                 "city": "san jose",
#                 "public_circuit_1": "att",
#                 "public_circuit_2": "comcast",
#                 "private_circuit": "VZ",
#                 "private_interface_subnet": "10.20.30.",
#                 "ion_name_1": "testion",
#                 "ion_serial_number_1": "",
#                 "site_name": "test322",
#                 "street": "123 main",
#                 "post_code": "95134",
#                 "ion_sw_version": "6.2.2-b1",
#                 "state": "CA",
#                 "interface1_subnet": "20.10.20."
#             },
#             "deployment_id": "1711137575850022896",
#             "template_id": "1710109635377014196",
#             "site_id": "1711137579102020996",
#             "site_name": "test322",
#             "status": "SUCCESS",
#             "status_description": "Successfully deployed site 'test322",
#             "template_name": "West Coast Deployment",
#             "_created_by_operator_id": "1706805074765011896",
#             "_updated_by_operator_id": "1706805074765011896",
#             "isSiteDeleted": false,
#             "elements": [
#                 {
#                     "id": "17111375817680186",
#                     "_created_on_utc": 17111375817720187,
#                     "_updated_on_utc": 17111375817830188,
#                     "_debug": null,
#                     "_info": null,
#                     "_warning": null,
#                     "_error": null,
#                     "hw_id": "SHELL#1711137581772018796",
#                     "name": "testion",
#                     "connected": "false",
#                     "device_type": "SHELL"
#                 }
#             ]
#         }
#     ],
#     "next_query": {
#         "getDeleted": {
#             "eq": true
#         },
#         "sort_params": {
#             "_updated_on_utc": "desc"
#         },
#         "total_count": {
#             "eq": 19
#         },
#         "limit": {
#             "eq": 10
#         }
#     },
#     "total_count": 19,
#     "deleted_count": 0
# }
