# %%
import prisma_sase

# %%
#
# Authenticate using Service Account - SASE Portal
#

CLIENT_ID = "paste client ID"
CLIENT_SECRET = "paste client secret"
TSG = "paste TSG ID"

sdk = prisma_sase.API(ssl_verify=False)
sdk.interactive.login_secret(client_id=CLIENT_ID, client_secret=CLIENT_SECRET, tsg_id=TSG)
# Out:
# True

# %% [markdown]
# # METRICS

# %% [markdown]
# ## Types of Metrics:
# - Site Health Score
# - Bandwidth Utilization
# - Transaction Stats
#     - Init Failures
#     - Transaction Failures
#     - Init Success
#     - Transaction Success
# - Application Response Time
#     - Round Trip Time
#     - Server Response Time
#     - Normalized Network Transfer Time
# - Application Health
# - New & Concurrent Flows
# - Link Quality Metrics
#     - Point Metrics
#     - Time Series
# - Media Metrics
#     - Bandwidth Utilization
#     - Jitter
#     - Packet Loss
#     - Audio MOS
# - Flow Data
# - Interface Metrics
#     - Bandwidth Utilization
#     - Dropped Packets
#     - Errors
# - System Metrics
#     - CPU Utilization
#     - Free Memory
#     - Device Temperature
#     - Free Disk
# - Cellular Metrics
#     - Signal Strength
#     - Signal Stats
#     - Traffic Volume
#     - Technologies
#     - Bandwidth Usage
#     - Packet Drops
#     - Packet Errors
#     - Packet Overflows
#     - GPS Locations
#     - Cellular Tower Switches
# - AAA Metrics
#     - EAP Packets
#     - EAP Messages
#     - Authentication

# %% [markdown]
# ## Metrics: Site Health Score

# %%
data = {
    "start_time": "2023-05-03T17:00:00Z",
    "end_time": "2023-05-03T18:00:00Z",
    "interval": "5min",
    "metrics": [
        {"name": "Healthscore","statistics": ["max"], "unit": "gauge"}
    ],
    "filter": {
        "site": ["1663699016854013396"]
    }
}
resp = sdk.post.metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.3/api/monitor/metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1 (PRISMA SASE SDK v6.1.2b1)
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: application/json
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....kOoeDI9gwv-HiLaV8BiaIB-yllHaXfBOimQPUNCh_-aNUIp_bs3Fkfi1nrC8iXDurYiQnFaxOxLLFmz2G7eV3X4qT9DCE2n8Fic54tcpOaNvysgcqb7bGjyy2j3IwpQKbggfdxeNPyd55QLaG9MgPByXLW4S53WeXcwomtvZ2oxtBuVm4cx3safHEiDP5eJRnFVIi3_0vTwokfz021MrNMSXMJQr4fYRfPPKrCZQ7jYARI-0rfJqv6o2ObJZPfKfTuILe3voWb6ypW8_IUNGrfiNuDS81YmEZETgvQxO4uzQL_Y3wYiqqzNRFVfNHSf-0uobs03yNoFzfKrNBHx9fg
# 	X-PANW-Region: americas
# 	Content-Type: application/json
# 	Content-Length: 217
# REQUEST BODY:
# {
#     "start_time": "2023-05-03T17:00:00Z",
#     "end_time": "2023-05-03T18:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "Healthscore",
# ...

# %% [markdown]
# ## Metrics: Bandwidth Utilization

# %%
#
# Additionally allowed filters: path, waninterfaces
# Group By: app, path_type by setting view to {"individual": "app"} or {"individual": "path_type"}
#

data = {
    "start_time": "2024-01-02T19:17:53.398Z",
    "end_time": "2024-01-09T18:12:53.399Z",
    "interval": "1hour",
    "metrics": [
        {
            "name": "BandwidthUsage",
            "statistics": ["average"],
            "unit": "Mbps"
        }
    ],
    "view": {"summary": True},
    "filter": {
        "site": ["1663699016854013396"],
        "app": [],
        "path_type": ["DirectInternet", "VPN", "PrivateVPN", "PrivateWAN", "ServiceLink"],
        "waninterfaces": []
    }
}

resp = sdk.post.metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.4/api/monitor/metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.31.0 (PRISMA SASE SDK v6.3.1b1)
# 	Accept-Encoding: gzip, deflate
# 	Accept: application/json
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....BNWYb5EpJjQpm2Fh2RVTe04E3L6bEep7k8q5t7nG5_luRso3OdgUE6faMkLKqQdA8BTvmwF4a5rI5legLILZpBfhLzsAzuv32z02lZ_31eDaNBv8Cx3lADtXWD8F7_avUu4HfDNxEsrPtTMcxeeV9wH0u-sp10AWgVPTTUHJPA_NPkf8hJedtn0AjBLElyl-O7zS0XfV5zj4C8SSzJ3aTDePVe4s2EWR-8QsF4RlGwJGonbAvH-RW7gvpmuiADo_Beky1SYxdM38A77fnvMTLZzu_9teRHjZNqjY0FNd3t62Cw7-HLG2ip6mv9PyXgQ1bmOhbtzNVvQbxUt_ijoGeQ
# 	X-PANW-Region: americas
# 	Content-Type: application/json
# 	Content-Length: 228
# REQUEST BODY:
# {
#     "start_time": "2024-01-02T19:17:53.398Z",
#     "end_time": "2024-01-09T18:12:53.399Z",
#     "interval": "1hour",
#     "metrics": [
#         {
#             "name": "BandwidthUsage",
# ...

# %% [markdown]
# ## Metrics: Transaction Stats

# %%
data = {
  "start_time": "2023-05-02T17:00:00Z",
  "end_time": "2023-05-02T18:00:00Z",
  "interval": "5min",
  "metrics": [
    {"name": "AppSuccessfulConnections", "statistics": ["sum"], "unit": "count"},
    {"name": "AppSuccessfulTransactions", "statistics": ["sum"], "unit": "count"},
    {"name": "AppFailedToEstablish", "statistics": ["sum"], "unit": "count"},
    {"name": "AppTransactionFailures", "statistics": ["sum"], "unit": "count"},    
  ],
  "view": {},
  "filter": {
    "site": ["1663699016854013396"],
    "app": [],
    "path_type": ["DirectInternet", "VPN", "PrivateVPN", "PrivateWAN", "ServiceLink"]
  }
}

resp = sdk.post.metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.3/api/monitor/metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1 (PRISMA SASE SDK v6.1.2b1)
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: application/json
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....kOoeDI9gwv-HiLaV8BiaIB-yllHaXfBOimQPUNCh_-aNUIp_bs3Fkfi1nrC8iXDurYiQnFaxOxLLFmz2G7eV3X4qT9DCE2n8Fic54tcpOaNvysgcqb7bGjyy2j3IwpQKbggfdxeNPyd55QLaG9MgPByXLW4S53WeXcwomtvZ2oxtBuVm4cx3safHEiDP5eJRnFVIi3_0vTwokfz021MrNMSXMJQr4fYRfPPKrCZQ7jYARI-0rfJqv6o2ObJZPfKfTuILe3voWb6ypW8_IUNGrfiNuDS81YmEZETgvQxO4uzQL_Y3wYiqqzNRFVfNHSf-0uobs03yNoFzfKrNBHx9fg
# 	X-PANW-Region: americas
# 	Content-Type: application/json
# 	Content-Length: 565
# REQUEST BODY:
# {
#     "start_time": "2023-05-02T17:00:00Z",
#     "end_time": "2023-05-02T18:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "AppSuccessfulConnections",
# ...

# %% [markdown]
# ## Metrics: Application Response Time

# %%
data = {
  "start_time": "2023-05-02T17:00:00Z",
  "end_time": "2023-05-02T18:00:00Z",
  "interval": "5min",
  "metrics": [
    {"name": "AppNormalizedNetworkTransferTime", "statistics": ["average"], "unit": "milliseconds"},
    {"name": "AppRoundTripTime", "statistics": ["average"], "unit": "milliseconds"},
    {"name": "AppServerResponseTime", "statistics": ["average"], "unit": "milliseconds"},
    {"name": "AppUDPTransactionResponseTime", "statistics": ["average"], "unit": "milliseconds"}
  ],
  "view": {},
  "filter": {
    "site": ["1663699016854013396"],
    "app": ["1660361193950024396"],
    "path_type": ["DirectInternet", "VPN", "PrivateVPN", "PrivateWAN", "ServiceLink"]
  }
}

resp = sdk.post.metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.3/api/monitor/metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1 (PRISMA SASE SDK v6.1.2b1)
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: application/json
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....kOoeDI9gwv-HiLaV8BiaIB-yllHaXfBOimQPUNCh_-aNUIp_bs3Fkfi1nrC8iXDurYiQnFaxOxLLFmz2G7eV3X4qT9DCE2n8Fic54tcpOaNvysgcqb7bGjyy2j3IwpQKbggfdxeNPyd55QLaG9MgPByXLW4S53WeXcwomtvZ2oxtBuVm4cx3safHEiDP5eJRnFVIi3_0vTwokfz021MrNMSXMJQr4fYRfPPKrCZQ7jYARI-0rfJqv6o2ObJZPfKfTuILe3voWb6ypW8_IUNGrfiNuDS81YmEZETgvQxO4uzQL_Y3wYiqqzNRFVfNHSf-0uobs03yNoFzfKrNBHx9fg
# 	X-PANW-Region: americas
# 	Content-Type: application/json
# 	Content-Length: 637
# REQUEST BODY:
# {
#     "start_time": "2023-05-02T17:00:00Z",
#     "end_time": "2023-05-02T18:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "AppNormalizedNetworkTransferTime",
# ...

# %% [markdown]
# ## Metrics: Concurrent Flows

# %%
data = {
  "start_time": "2023-05-02T17:00:00Z",
  "end_time": "2023-05-02T18:00:00Z",
  "interval": "5min",
  "metrics": [
    {"name": "TCPConcurrentFlows", "statistics": ["max"], "unit": "count"},
    {"name": "UDPConcurrentFlows", "statistics": ["max"], "unit": "count"}
  ],
  "view": {},
  "filter": {
    "site": ["1663699016854013396"],
    "app": ["1660361193950024396"],
    "path_type": ["DirectInternet", "VPN", "PrivateVPN", "PrivateWAN", "ServiceLink"]
  }
}

resp = sdk.post.metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.3/api/monitor/metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1 (PRISMA SASE SDK v6.1.2b1)
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: application/json
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....kOoeDI9gwv-HiLaV8BiaIB-yllHaXfBOimQPUNCh_-aNUIp_bs3Fkfi1nrC8iXDurYiQnFaxOxLLFmz2G7eV3X4qT9DCE2n8Fic54tcpOaNvysgcqb7bGjyy2j3IwpQKbggfdxeNPyd55QLaG9MgPByXLW4S53WeXcwomtvZ2oxtBuVm4cx3safHEiDP5eJRnFVIi3_0vTwokfz021MrNMSXMJQr4fYRfPPKrCZQ7jYARI-0rfJqv6o2ObJZPfKfTuILe3voWb6ypW8_IUNGrfiNuDS81YmEZETgvQxO4uzQL_Y3wYiqqzNRFVfNHSf-0uobs03yNoFzfKrNBHx9fg
# 	X-PANW-Region: americas
# 	Content-Type: application/json
# 	Content-Length: 423
# REQUEST BODY:
# {
#     "start_time": "2023-05-02T17:00:00Z",
#     "end_time": "2023-05-02T18:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "TCPConcurrentFlows",
# ...

# %% [markdown]
# ## Metrics: New Flows

# %%
data = {
  "start_time": "2023-05-02T17:00:00Z",
  "end_time": "2023-05-02T18:00:00Z",
  "interval": "5min",
  "metrics": [
    {"name": "TCPFlowCount", "statistics": ["sum"], "unit": "count"},
    {"name": "UDPFlowCount", "statistics": ["sum"], "unit": "count"}
  ],
  "view": {},
  "filter": {
    "site": ["1663699016854013396"],
    "app": ["1660361193950024396"],
    "path_type": ["DirectInternet", "VPN", "PrivateVPN", "PrivateWAN", "ServiceLink"]
  }
}

resp = sdk.post.metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.3/api/monitor/metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1 (PRISMA SASE SDK v6.1.2b1)
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: application/json
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....kOoeDI9gwv-HiLaV8BiaIB-yllHaXfBOimQPUNCh_-aNUIp_bs3Fkfi1nrC8iXDurYiQnFaxOxLLFmz2G7eV3X4qT9DCE2n8Fic54tcpOaNvysgcqb7bGjyy2j3IwpQKbggfdxeNPyd55QLaG9MgPByXLW4S53WeXcwomtvZ2oxtBuVm4cx3safHEiDP5eJRnFVIi3_0vTwokfz021MrNMSXMJQr4fYRfPPKrCZQ7jYARI-0rfJqv6o2ObJZPfKfTuILe3voWb6ypW8_IUNGrfiNuDS81YmEZETgvQxO4uzQL_Y3wYiqqzNRFVfNHSf-0uobs03yNoFzfKrNBHx9fg
# 	X-PANW-Region: americas
# 	Content-Type: application/json
# 	Content-Length: 411
# REQUEST BODY:
# {
#     "start_time": "2023-05-02T17:00:00Z",
#     "end_time": "2023-05-02T18:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "TCPFlowCount",
# ...

# %% [markdown]
# ## Metrics: App Health

# %%
data = {
  "start_time": "2023-05-02T17:00:00Z",
  "end_time": "2023-05-02T18:00:00Z",
  "interval": "5min",
  "metrics": [
    {"name": "AppUnreachable", "statistics": ["max"], "unit": "count"},
    {"name": "AppSiteHealth", "statistics": ["max"], "unit": "count"}
  ],
  "view": {"individual":"path_type"},
  "filter": {
    "site": ["1663699016854013396"],
    "app": ["1660361193950024396"],
    "path_type": ["DirectInternet", "VPN", "PrivateVPN", "PrivateWAN", "ServiceLink"]
  }
}

resp = sdk.post.metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.3/api/monitor/metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1 (PRISMA SASE SDK v6.1.2b1)
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: application/json
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....kOoeDI9gwv-HiLaV8BiaIB-yllHaXfBOimQPUNCh_-aNUIp_bs3Fkfi1nrC8iXDurYiQnFaxOxLLFmz2G7eV3X4qT9DCE2n8Fic54tcpOaNvysgcqb7bGjyy2j3IwpQKbggfdxeNPyd55QLaG9MgPByXLW4S53WeXcwomtvZ2oxtBuVm4cx3safHEiDP5eJRnFVIi3_0vTwokfz021MrNMSXMJQr4fYRfPPKrCZQ7jYARI-0rfJqv6o2ObJZPfKfTuILe3voWb6ypW8_IUNGrfiNuDS81YmEZETgvQxO4uzQL_Y3wYiqqzNRFVfNHSf-0uobs03yNoFzfKrNBHx9fg
# 	X-PANW-Region: americas
# 	Content-Type: application/json
# 	Content-Length: 439
# REQUEST BODY:
# {
#     "start_time": "2023-05-02T17:00:00Z",
#     "end_time": "2023-05-02T18:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "AppUnreachable",
# ...

# %% [markdown]
# ## Metrics: Link Quality Metrics - Time Series
# - Jitter
# - Packet Loss
# - Link MOS

# %%
data = {
  "start_time": "2023-05-24T17:00:00Z",
  "end_time": "2023-05-24T18:00:00Z",
  "interval": "5min",
  "metrics": [
    {"name": "LqmJitter", "statistics": ["average"], "unit": "milliseconds"},
    {"name": "LqmPacketLoss", "statistics": ["average"], "unit": "Percentage"},
    {"name": "LqmMos", "statistics": ["average"], "unit": "count"}
  ],
  "view": {},
  "filter": {
    "direction": "Ingress",
    "site": ["1663699016854013396"],
    "path": ["1663699017991018296"]
  }
}

resp = sdk.post.metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.3/api/monitor/metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: */*
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....pOVqKjkP9G6cTCu8rqMjOCgDFBKKnUJIrxGP5lskuflzNzPNIOHl365YYG3VqkPYwYNru48lGIL7B1Pcdh7u6i7B-IKIUeJ5mR2m0uwQuRWssrv06dQoPUKdK35ooUCvngH_g85PSePTCxvujPVJgYlgkMqIQQKy_5Y-NgEnZPPpo1XCIkSEHfh95vrPcjaWgXqrH_5BtR2-_7PfHgH8EkXrfsmpZYYAGSi-oq1AdDvOPODKcihOi2ZKy9lcdO2P57M75e2_er9Hk6-A1B0xWMETkc2Nt4Kv61ATfba7oGPY-kry6OA498xyo8bZgjf--s5NJ2PdhKLWoZ-vm4P5Bw
# 	Content-Type: application/json
# 	Content-Length: 435
# REQUEST BODY:
# {
#     "start_time": "2023-05-24T17:00:00Z",
#     "end_time": "2023-05-24T18:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "LqmJitter",
#             "statistics": [
#                 "average"
#             ],
# ...

# %% [markdown]
# ## Metrics: Link Quality Metrics - Time Series
# - Link Health
# - Latency

# %%
data = {
  "start_time": "2023-05-02T17:00:00Z",
  "end_time": "2023-05-02T18:00:00Z",
  "interval": "5min",
  "metrics": [
    {"name": "LqmLinkHealth", "statistics": ["min"], "unit": "count"},
    {"name": "LqmLatency", "statistics": ["average"], "unit": "milliseconds"}
  ],
  "view": {},
  "filter": {
    "site": ["1663699016854013396"],
    "path": ["1663699017991018296"]
  }
}

resp = sdk.post.metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.3/api/monitor/metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: */*
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....pOVqKjkP9G6cTCu8rqMjOCgDFBKKnUJIrxGP5lskuflzNzPNIOHl365YYG3VqkPYwYNru48lGIL7B1Pcdh7u6i7B-IKIUeJ5mR2m0uwQuRWssrv06dQoPUKdK35ooUCvngH_g85PSePTCxvujPVJgYlgkMqIQQKy_5Y-NgEnZPPpo1XCIkSEHfh95vrPcjaWgXqrH_5BtR2-_7PfHgH8EkXrfsmpZYYAGSi-oq1AdDvOPODKcihOi2ZKy9lcdO2P57M75e2_er9Hk6-A1B0xWMETkc2Nt4Kv61ATfba7oGPY-kry6OA498xyo8bZgjf--s5NJ2PdhKLWoZ-vm4P5Bw
# 	Content-Type: application/json
# 	Content-Length: 339
# REQUEST BODY:
# {
#     "start_time": "2023-05-02T17:00:00Z",
#     "end_time": "2023-05-02T18:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "LqmLinkHealth",
#             "statistics": [
#                 "min"
#             ],
# ...

# %% [markdown]
# ## Metrics: Link Quality Metrics - Point Metrics

# %%
data = {
    "start_time":"2023-05-01T00:00:00Z",
    "interval":"1day",
    "filter":{
        "site": ["1663699016854013396"],
        "path":[]
    },
    "metrics":[
        {"name":"LqmLatencyPointMetric","unit":"milliseconds"},
        {"name":"LqmMosPointMetric","unit":"count"},
        {"name":"LqmPktLossPointMetric","unit":"percentage"},
        {"name":"LqmJitterPointMetric","unit":"milliseconds"}
    ]
}
resp = sdk.post.lqm_point_metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.0/api/monitor/lqm_point_metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: */*
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....pOVqKjkP9G6cTCu8rqMjOCgDFBKKnUJIrxGP5lskuflzNzPNIOHl365YYG3VqkPYwYNru48lGIL7B1Pcdh7u6i7B-IKIUeJ5mR2m0uwQuRWssrv06dQoPUKdK35ooUCvngH_g85PSePTCxvujPVJgYlgkMqIQQKy_5Y-NgEnZPPpo1XCIkSEHfh95vrPcjaWgXqrH_5BtR2-_7PfHgH8EkXrfsmpZYYAGSi-oq1AdDvOPODKcihOi2ZKy9lcdO2P57M75e2_er9Hk6-A1B0xWMETkc2Nt4Kv61ATfba7oGPY-kry6OA498xyo8bZgjf--s5NJ2PdhKLWoZ-vm4P5Bw
# 	Content-Type: application/json
# 	Content-Length: 350
# REQUEST BODY:
# {
#     "start_time": "2023-05-01T00:00:00Z",
#     "interval": "1day",
#     "filter": {
#         "site": [
#             "1663699016854013396"
#         ],
#         "path": []
#     },
#     "metrics": [
#         {
# ...

# %% [markdown]
# ## Metrics: Flows

# %%
data = {
  "start_time": "2023-05-03T17:07:00Z",
  "end_time": "2023-05-03T17:08:00Z",
  "filter": {
      "app": [],
      "site": ["1663699016854013396"],
      "path": []
  },
  "debug_level": "all"
}

resp = sdk.post.flows_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v3.6/api/monitor/flows
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: */*
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....pOVqKjkP9G6cTCu8rqMjOCgDFBKKnUJIrxGP5lskuflzNzPNIOHl365YYG3VqkPYwYNru48lGIL7B1Pcdh7u6i7B-IKIUeJ5mR2m0uwQuRWssrv06dQoPUKdK35ooUCvngH_g85PSePTCxvujPVJgYlgkMqIQQKy_5Y-NgEnZPPpo1XCIkSEHfh95vrPcjaWgXqrH_5BtR2-_7PfHgH8EkXrfsmpZYYAGSi-oq1AdDvOPODKcihOi2ZKy9lcdO2P57M75e2_er9Hk6-A1B0xWMETkc2Nt4Kv61ATfba7oGPY-kry6OA498xyo8bZgjf--s5NJ2PdhKLWoZ-vm4P5Bw
# 	Content-Type: application/json
# 	Content-Length: 164
# REQUEST BODY:
# {
#     "start_time": "2023-05-03T17:07:00Z",
#     "end_time": "2023-05-03T17:08:00Z",
#     "filter": {
#         "app": [],
#         "site": [
#             "1663699016854013396"
#         ],
#         "path": []
#     },
#     "debug_level": "all"
# }
#
# ...

# %% [markdown]
# ## Metrics: Sys Metrics
# - CPU Utilization
# - Free Memory
# - Free Disk

# %%
data = {
    "start_time": "2023-05-02T18:00:00Z",
    "end_time": "2023-05-02T19:00:00Z",
    "interval": "5min",
    "metrics": [
        {"name": "CPUUsage", "statistics": ["max"], "unit": "percentage"},
        {"name":"MemoryUsage","statistics":["max"],"unit":"percentage"},
        {"name":"DiskUsage","statistics":["max"],"unit":"percentage"},

    ],
    "filter": {
        "site": ["1663699016854013396"],
        "element": ["1679333011928014596"]
    }
}

resp = sdk.post.sys_metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.2/api/monitor/sys_metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: */*
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....NW2_L5sUkD0hplYMoy9GujSj1X1Iv_TrD22MPJGn5E0KhI3rTygITEfCefpv-7fQilhZVifVHkwrECvacZOdeJz_sO_2XV10Ao7IMuY3DzbIcpObugC0jJipxrQUcRFj41dq7paMRahp_Z2qMvnSwH62Bo70GI4SEHMi2ePNvDyW9ufcvLgUCI8FllVQ7DcDoCsCD-fs45zDU6pCaHsyfH7ymvkSzgAR9pRAMbjFFiHvLxXRrnpmsdtly0L4cFfYQoJ06aL1p1EVMe-QfP0KCDxvaXwUsPyns8y5ALw_RL3LcYYt2wJpwG4RL3OKfZGWb6UGt_6v-wsrH0VfmfhmhA
# 	Content-Type: application/json
# 	Content-Length: 393
# REQUEST BODY:
# {
#     "start_time": "2023-05-02T18:00:00Z",
#     "end_time": "2023-05-02T19:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "CPUUsage",
#             "statistics": [
#                 "max"
#             ],
# ...

# %% [markdown]
# ## Metrics: Device Temperature

# %%
data = {
    "start_time": "2023-05-02T18:00:00Z",
    "end_time": "2023-05-02T19:00:00Z",
    "interval": "5min",
    "metrics": [
        {"name": "DeviceCpuTemperature", "statistics": ["average"], "unit": "celsius"},
        {"name": "DeviceAcpiTemperature", "statistics": ["average"], "unit": "celsius"},
        {"name": "DeviceModemTemperature", "statistics": ["average"], "unit": "celsius"},
        {"name": "DeviceInletTemperature", "statistics": ["average"], "unit": "celsius"},
        {"name": "DeviceOutletTemperature", "statistics": ["average"], "unit": "celsius"},
        {"name": "DevicePseTemperature", "statistics": ["average"], "unit": "celsius"}
    ],
    "view": {
        "individual": "element",
        "summary": False
    },
    "filter": {
        "site": ["1663699016854013396"],
        "element": ["1679333011928014596"]
    }
}

resp = sdk.post.sys_metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.2/api/monitor/sys_metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: */*
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....NW2_L5sUkD0hplYMoy9GujSj1X1Iv_TrD22MPJGn5E0KhI3rTygITEfCefpv-7fQilhZVifVHkwrECvacZOdeJz_sO_2XV10Ao7IMuY3DzbIcpObugC0jJipxrQUcRFj41dq7paMRahp_Z2qMvnSwH62Bo70GI4SEHMi2ePNvDyW9ufcvLgUCI8FllVQ7DcDoCsCD-fs45zDU6pCaHsyfH7ymvkSzgAR9pRAMbjFFiHvLxXRrnpmsdtly0L4cFfYQoJ06aL1p1EVMe-QfP0KCDxvaXwUsPyns8y5ALw_RL3LcYYt2wJpwG4RL3OKfZGWb6UGt_6v-wsrH0VfmfhmhA
# 	Content-Type: application/json
# 	Content-Length: 729
# REQUEST BODY:
# {
#     "start_time": "2023-05-02T18:00:00Z",
#     "end_time": "2023-05-02T19:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "DeviceCpuTemperature",
#             "statistics": [
#                 "average"
#             ],
# ...

# %% [markdown]
# ## Metrics: Interface Metrics

# %%
data = {
    "start_time": "2023-05-02T18:00:00Z",
    "end_time": "2023-05-02T19:00:00Z",
    "interval": "5min",
    "metrics": [
        {"name":"InterfaceBandwidthUsage","statistics":["average"],"unit":"Mbps"},
        {"name":"InterfaceDroppedPackets","statistics":["sum"],"unit":"count"},
        {"name":"InterfaceErrors","statistics":["sum"],"unit":"count"}
    ],
    "filter": {
        "site": ["1663699016854013396"],
        "element": ["1679333011928014596"],
        "interface":["1684864998229000896"]
    }
}

resp = sdk.post.sys_metrics_monitor(data=data)
prisma_sase.jd_detailed(resp)
# Out:
# REQUEST: POST /sdwan/monitor/v2.2/api/monitor/sys_metrics
# REQUEST HEADERS:
# 	User-Agent: python-requests/2.28.1
# 	Accept-Encoding: gzip, deflate, br
# 	Accept: */*
# 	Connection: keep-alive
# 	authorization: Bearer eyJ0eXAiOiJKV1QiLCJraWQiOiJyc2Etc2lnbi1wa2NzMS0yMDQ4LXNoYTI1Ni8xIiwiYWxnIjoiUlMyNTYifQ.....NW2_L5sUkD0hplYMoy9GujSj1X1Iv_TrD22MPJGn5E0KhI3rTygITEfCefpv-7fQilhZVifVHkwrECvacZOdeJz_sO_2XV10Ao7IMuY3DzbIcpObugC0jJipxrQUcRFj41dq7paMRahp_Z2qMvnSwH62Bo70GI4SEHMi2ePNvDyW9ufcvLgUCI8FllVQ7DcDoCsCD-fs45zDU6pCaHsyfH7ymvkSzgAR9pRAMbjFFiHvLxXRrnpmsdtly0L4cFfYQoJ06aL1p1EVMe-QfP0KCDxvaXwUsPyns8y5ALw_RL3LcYYt2wJpwG4RL3OKfZGWb6UGt_6v-wsrH0VfmfhmhA
# 	Content-Type: application/json
# 	Content-Length: 452
# REQUEST BODY:
# {
#     "start_time": "2023-05-02T18:00:00Z",
#     "end_time": "2023-05-02T19:00:00Z",
#     "interval": "5min",
#     "metrics": [
#         {
#             "name": "InterfaceBandwidthUsage",
#             "statistics": [
#                 "average"
#             ],
# ...
